# %% [markdown]
# <a href="https://colab.research.google.com/github/JuliaKovalchook/Date-generator/blob/main/GeoPanda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

overpass_url = "https://overpass-api.de/api/interpreter?data="
overpass_query = '''
[out:json];
area['name:uk'='Одеська область'];
(rel['admin_level'='6'](area););
out geom;
'''
response = requests.get(overpass_url,  params={'data': overpass_query})
data = response.json()
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.61.5 4133829e',
#  'osm3s': {'timestamp_osm_base': '2023-11-08T10:34:58Z',
#   'timestamp_areas_base': '2023-11-08T05:28:00Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'relation',
#    'id': 11821462,
#    'bounds': {'minlat': 45.2032905,
#     'minlon': 28.2138288,
#     'maxlat': 45.8133408,
#     'maxlon': 30.2075328},
#    'members': [{'type': 'node',
#      'ref': 337696139,
#      'role': 'admin_centre',
#      'lat': 45.3511307,
#      'lon': 28.8361514},
#     {'type': 'way',
#      'ref': 974942740,
#      'role': 'inner',
#      'geometry': [{'lat': 45.4583772, 'lon': 28.710431},
#       {'lat': 45.4587582, 'lon': 28.7112491},
#       {'lat': 45.4591777, 'lon': 28.7122603},
#       {'lat': 45.459745, 'lon': 28.7120122},
#       {'lat': 45.4599465, 'lon': 28.7117855},
#       {'lat': 45.4609189, 'lon': 28.7110868},
# ...
